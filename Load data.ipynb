# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt

# %%
all_files=[]
import os
for root, dirs, files in os.walk("data/"):
    for file in files:
        if file.endswith(".csv"):
             all_files.append(os.path.join(root, file))

# %%
experiments = {'data/other\\13.csv':'Sharply behavior of rotor imbalance',
               'data/other\\14.csv':'Linear behavior of rotor imbalance',
               'data/other\\15.csv':'Step behavior of rotor imbalance',
               'data/other\\16.csv':'Dirac delta function behavior of rotor imbalance',
               'data/other\\17.csv':'Exponential behavior of rotor imbalance',
               'data/other\\18.csv':'The slow increase in the amount of water in the circuit',
               'data/other\\19.csv':'The sudden increase in the amount of water in the circuit',
               'data/other\\20.csv':'Draining water from the tank until cavitation',
               'data/other\\21.csv':'Two-phase flow supply to the pump inlet (cavitation)',
               'data/other\\22.csv':'Water supply of increased temperature',
# Out:
#   File "<ipython-input-3-3a4de1ebca35>", line 10
#     'data/other\\22.csv':'Water supply of increased temperature',
#                                                                  ^
# SyntaxError: unexpected EOF while parsing

# %%
my_dict = {}

# %%
dfs=[]
for path in all_files:
    df = pd.read_csv(path,index_col='datetime',sep=';',parse_dates=True)
    dfs.append(df)
    print(len(df),df.index[-1]-df.index[0])
    plt.plot(df['Volume Flow RateRMS'].rolling(5).mean().values,label=path)
plt.legend()
# Out:
# 665 0 days 00:15:36
# 1137 0 days 00:19:58
# 968 0 days 00:17:00
# 1153 0 days 00:20:08
# 1147 0 days 00:20:00
# 1091 0 days 00:19:02
# 1147 0 days 00:20:02
# 1145 0 days 00:20:00
# 1326 0 days 00:23:18
# 1191 0 days 00:20:54
# 1141 0 days 00:20:03
# 1079 0 days 00:18:57
# 1044 0 days 00:18:17
# 751 0 days 00:13:07
# 1148 0 days 00:19:59
# 1145 0 days 00:20:00
# 1146 0 days 00:19:59
# 1141 0 days 00:20:00
# 1140 0 days 00:20:00
# 1140 0 days 00:19:59
# 1139 0 days 00:19:59
# 1150 0 days 00:20:00
# 1075 0 days 00:19:59
# 1149 0 days 00:20:01
# 1095 0 days 00:19:59
# 1154 0 days 00:19:59
# 1154 0 days 00:19:59
# 1094 0 days 00:20:00
# 1144 0 days 00:19:58
# 1148 0 days 00:20:00
# 1125 0 days 00:19:59
# 1063 0 days 00:20:00
# 1129 0 days 00:19:59
# 995 0 days 00:17:38

# %%
# dfs=[]
# for path in all_files:
#     if 'other' in path:
#         df = pd.read_csv(path,index_col='datetime',sep=';',parse_dates=True)
#         dfs.append(df)
#         print(len(df),df.index[-1]-df.index[0])
#         plt.plot(df['Volume Flow RateRMS'].rolling(5).mean().values,label=path)
# plt.legend()
# Out:
# 665 0 days 00:15:36
# 1137 0 days 00:19:58
# 968 0 days 00:17:00
# 1153 0 days 00:20:08
# 1147 0 days 00:20:00
# 1091 0 days 00:19:02
# 1147 0 days 00:20:02
# 1145 0 days 00:20:00
# 1326 0 days 00:23:18
# 1191 0 days 00:20:54
# 1141 0 days 00:20:03
# 1079 0 days 00:18:57
# 1044 0 days 00:18:17
# 751 0 days 00:13:07

# %%
dfs[0].columns
# Out:
# Index(['Accelerometer1RMS', 'Accelerometer2RMS', 'Current', 'Pressure',
#        'Temperature', 'Thermocouple', 'Voltage', 'Volume Flow RateRMS',
#        'anomaly', 'changepoint'],
#       dtype='object')

# %%
dfs[0]['Volume Flow RateRMS'].plot()

# %%
dfs[0].anomaly.plot()

# %%
dfs=[]
for path in all_files:
    if 'other' in path:
        if '\7.' in path or '\18.' in path:
            df = pd.read_csv(path,index_col='datetime',sep=';',parse_dates=True)
            dfs.append(df)
            print(len(df),df.index[-1]-df.index[0])
            plt.plot(df['Volume Flow RateRMS'].rolling(5).mean().values,label=path)
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %%
dfs[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-45eca48fe58f> in <module>
# ----> 1 dfs[0]
#
# IndexError: list index out of range

# %%
from sklearn.preprocessing import MinMaxScaler
for i in range(len(dfs)):
    plt.figure()
    
#     kk = dfs[i].copy()
#     kk[kk.columns] = MinMaxScaler().fit_transform(dfs[i])
#     kk.plot(legend=False,figsize=(12,5))
    dfs[i].plot(legend=False,figsize=(12,5))
    for line in dfs[i][dfs[i].changepoint == 1].index:
        plt.axvline(line,c='r')
    plt.show()
